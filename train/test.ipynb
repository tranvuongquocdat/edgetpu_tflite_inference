# %%
from vision.datasets.slr_dataset import SLRDataset
from config import default_config as cfg
import numpy as np

# Khởi tạo dataset
dataset = SLRDataset(root=cfg.datasets[0], transform=None, target_transform=None)

# Danh sách để lưu các mẫu có vấn đề
problematic_samples = []

# Duyệt qua toàn bộ dataset
for i in range(len(dataset)):
    try:
        image, boxes, labels = dataset[i]
        print(f"Sample {i} (ID: {dataset.ids[i]}): Checking data...")
        
        # Kiểm tra image
        if image is None:
            problematic_samples.append((i, dataset.ids[i], "Image is None"))
            print(f"Sample {i} (ID: {dataset.ids[i]}): Image is None")
            continue
        
        # Kiểm tra boxes
        if boxes is None:
            problematic_samples.append((i, dataset.ids[i], "Boxes is None"))
            print(f"Sample {i} (ID: {dataset.ids[i]}): Boxes is None")
        elif not isinstance(boxes, np.ndarray):
            problematic_samples.append((i, dataset.ids[i], f"Boxes is not a NumPy array: {type(boxes)}"))
            print(f"Sample {i} (ID: {dataset.ids[i]}): Boxes is not a NumPy array: {type(boxes)}")
        elif len(boxes.shape) != 2 or boxes.shape[1] != 4:
            problematic_samples.append((i, dataset.ids[i], f"Invalid boxes shape: {boxes.shape}"))
            print(f"Sample {i} (ID: {dataset.ids[i]}): Invalid boxes shape: {boxes.shape}")
        else:
            print(f"Sample {i} (ID: {dataset.ids[i]}): Boxes shape={boxes.shape}")

        # Kiểm tra labels
        if labels is None:
            problematic_samples.append((i, dataset.ids[i], "Labels is None"))
            print(f"Sample {i} (ID: {dataset.ids[i]}): Labels is None")
        elif not isinstance(labels, np.ndarray):
            problematic_samples.append((i, dataset.ids[i], f"Labels is not a NumPy array: {type(labels)}"))
            print(f"Sample {i} (ID: {dataset.ids[i]}): Labels is not a NumPy array: {type(labels)}")
        elif len(labels.shape) != 1:
            problematic_samples.append((i, dataset.ids[i], f"Invalid labels shape: {labels.shape}"))
            print(f"Sample {i} (ID: {dataset.ids[i]}): Invalid labels shape: {labels.shape}")
        else:
            print(f"Sample {i} (ID: {dataset.ids[i]}): Labels shape={labels.shape}")

        # Kiểm tra sự khớp nhau giữa boxes và labels
        if boxes.shape[0] != labels.shape[0]:
            problematic_samples.append((i, dataset.ids[i], f"Mismatch between boxes ({boxes.shape[0]}) and labels ({labels.shape[0]})"))
            print(f"Sample {i} (ID: {dataset.ids[i]}): Mismatch between boxes ({boxes.shape[0]}) and labels ({labels.shape[0]})")

    except ValueError as e:
        problematic_samples.append((i, dataset.ids[i], f"ValueError: {str(e)}"))
        print(f"Sample {i} (ID: {dataset.ids[i]}): ValueError: {str(e)}")
    except Exception as e:
        problematic_samples.append((i, dataset.ids[i], f"Other error: {str(e)}"))
        print(f"Sample {i} (ID: {dataset.ids[i]}): Other error: {str(e)}")

# In tóm tắt các mẫu có vấn đề
if problematic_samples:
    print("\nProblematic samples found:")
    for idx, image_id, issue in problematic_samples:
        print(f"Sample {idx} (ID: {image_id}): {issue}")
    print(f"Total problematic samples: {len(problematic_samples)}")
else:
    print("No problematic samples found in the dataset.")
# Out:
# Sample 0 (ID: C0002_test_jpg.rf.a3a79aa448c3298fe676599bec81dd85): Checking data...
# Sample 0 (ID: C0002_test_jpg.rf.a3a79aa448c3298fe676599bec81dd85): Boxes shape=(1, 4)
# Sample 0 (ID: C0002_test_jpg.rf.a3a79aa448c3298fe676599bec81dd85): Labels shape=(1,)
# Sample 1 (ID: WIN_20240221_23_46_54_Pro_jpg.rf.73d7f669db5e45a1bc3a6d690e7eb759): Checking data...
# Sample 10 (ID: 226_jpg.rf.745a3fab722b6ab3a08436c013859a93): Labels shape=(1,)
# Sample 11 (ID: hand1_j_bot_seg_1_cropped_jpeg.rf.64641af5a197aa6ae836a143e3f8ceba): Checking data...
# Sample 11 (ID: hand1_j_bot_seg_1_cropped_jpeg.rf.64641af5a197aa6ae836a143e3f8ceba): Boxes shape=(1, 4)
# Sample 11 (ID: hand1_j_bot_seg_1_cropped_jpeg.rf.64641af5a197aa6ae836a143e3f8ceba): Labels shape=(1,)
# Sample 12 (ID: hand2_l_bot_seg_4_cropped_jpeg.rf.adbc72798283d58866e2a17d12cb77b6): Checking data...
# Sample 12 (ID: hand2_l_bot_seg_4_cropped_jpeg.rf.adbc72798283d58866e2a17d12cb77b6): Boxes shape=(1, 4)
# Sample 12 (ID: hand2_l_bot_seg_4_cropped_jpeg.rf.adbc72798283d58866e2a17d12cb77b6): Labels shape=(1,)
# Sample 13 (ID: T93_jpg.rf.d19760d075d44e6f51ca13d8a54f5d21): Checking data...
# Sample 13 (ID: T93_jpg.rf.d19760d075d44e6f51ca13d8a54f5d21): Boxes shape=(1, 4)
# Sample 13 (ID: T93_jpg.rf.d19760d075d44e6f51ca13d8a54f5d21): Labels shape=(1,)
# Sample 14 (ID: hand1_w_right_seg_2_cropped_jpeg.rf.95ff123465f2f894b05a68b1755e98e3): Checking data...
# Sample 14 (ID: hand1_w_right_seg_2_cropped_jpeg.rf.95ff123465f2f894b05a68b1755e98e3): Boxes shape=(1, 4)
# Sample 14 (ID: hand1_w_right_seg_2_cropped_jpeg.rf.95ff123465f2f894b05a68b1755e98e3): Labels shape=(1,)
# Sample 15 (ID: hand5_g_bot_seg_1_cropped_jpeg.rf.ce1bebabb8ec9c7127b2e7a78df9de8a): Checking data...
# Sample 15 (ID: hand5_g_bot_seg_1_cropped_jpeg.rf.ce1bebabb8ec9c7127b2e7a78df9de8a): Boxes shape=(1, 4)
# Sample 15 (ID: hand5_g_bot_seg_1_cropped_jpeg.rf.ce1bebabb8ec9c7127b2e7a78df9de8a): Labels shape=(1,)
# Sample 16 (ID: I19_jpg.rf.ea9fa5d6fafee0c450d4d6f74258641b): Checking data...
# Sample 16 (ID: I19_jpg.rf.ea9fa5d6fafee0c450d4d6f74258641b): Boxes shape=(1, 4)
# Sample 16 (ID: I19_jpg.rf.ea9fa5d6fafee0c450d4d6f74258641b): Labels shape=(1,)
# Sample 17 (ID: hand2_n_right_seg_1_cropped_jpeg.rf.fe5624722f26f6c21e84a5f0a192ab53): Checking data...
# Sample 17 (ID: hand2_n_right_seg_1_cropped_jpeg.rf.fe5624722f26f6c21e84a5f0a192ab53): Boxes shape=(1, 4)
# Sample 17 (ID: hand2_n_right_seg_1_cropped_jpeg.rf.fe5624722f26f6c21e84a5f0a192ab53): Labels shape=(1,)
# Sample 18 (ID: 78_jpg.rf.972084aec4fa8a9abeea07c7f25fb3d5): Checking data...
# Sample 18 (ID: 78_jpg.rf.972084aec4fa8a9abeea07c7f25fb3d5): Boxes shape=(1, 4)
# Sample 117 (ID: 180_jpg.rf.9c5a61fe7eaf652716090ae672fafe84): Labels shape=(1,)
# Sample 118 (ID: 123_jpg.rf.f23d5743cd0f239da8832fec8a80f1b8): Checking data...
# Sample 118 (ID: 123_jpg.rf.f23d5743cd0f239da8832fec8a80f1b8): Boxes shape=(1, 4)
# Sample 118 (ID: 123_jpg.rf.f23d5743cd0f239da8832fec8a80f1b8): Labels shape=(1,)
# Sample 119 (ID: T3_jpg.rf.d96a975bead119226e976f56d677ed38): Checking data...
# Sample 119 (ID: T3_jpg.rf.d96a975bead119226e976f56d677ed38): Boxes shape=(1, 4)
# Sample 119 (ID: T3_jpg.rf.d96a975bead119226e976f56d677ed38): Labels shape=(1,)
# Sample 120 (ID: G415_jpg.rf.d1daec4c0ce52df636561672123c03b1): Checking data...
# Sample 120 (ID: G415_jpg.rf.d1daec4c0ce52df636561672123c03b1): Boxes shape=(1, 4)
# Sample 120 (ID: G415_jpg.rf.d1daec4c0ce52df636561672123c03b1): Labels shape=(1,)
# Sample 121 (ID: 201-6-59-53-PM_jpg.rf.2dd3b9e4775d447e69423ef5085e8a37): Checking data...
# Sample 121 (ID: 201-6-59-53-PM_jpg.rf.2dd3b9e4775d447e69423ef5085e8a37): Boxes shape=(1, 4)
# Sample 121 (ID: 201-6-59-53-PM_jpg.rf.2dd3b9e4775d447e69423ef5085e8a37): Labels shape=(1,)
# Sample 122 (ID: C2_jpg.rf.c6a192f1fb1c6d713fae0fff0d367539): Checking data...
# Sample 122 (ID: C2_jpg.rf.c6a192f1fb1c6d713fae0fff0d367539): Boxes shape=(1, 4)
# Sample 122 (ID: C2_jpg.rf.c6a192f1fb1c6d713fae0fff0d367539): Labels shape=(1,)
# Sample 123 (ID: hand2_m_left_seg_1_cropped_jpeg.rf.3810250b4b354d6c6408041e8f021b88): Checking data...
# Sample 123 (ID: hand2_m_left_seg_1_cropped_jpeg.rf.3810250b4b354d6c6408041e8f021b88): Boxes shape=(1, 4)
# Sample 123 (ID: hand2_m_left_seg_1_cropped_jpeg.rf.3810250b4b354d6c6408041e8f021b88): Labels shape=(1,)
# Sample 124 (ID: hand1_r_dif_seg_4_cropped_jpeg.rf.270034e2e0cf38486d0f6e1745c019eb): Checking data...
# Sample 124 (ID: hand1_r_dif_seg_4_cropped_jpeg.rf.270034e2e0cf38486d0f6e1745c019eb): Boxes shape=(1, 4)
# Sample 124 (ID: hand1_r_dif_seg_4_cropped_jpeg.rf.270034e2e0cf38486d0f6e1745c019eb): Labels shape=(1,)
# Sample 125 (ID: O22_jpg.rf.00e038e65385130191531c40cc376099): Checking data...
# Sample 125 (ID: O22_jpg.rf.00e038e65385130191531c40cc376099): Boxes shape=(1, 4)
# Sample 125 (ID: O22_jpg.rf.00e038e65385130191531c40cc376099): Labels shape=(1,)
# Sample 126 (ID: 57_jpg.rf.46095db00eb3fcedceaec65446ed2891): Checking data...
# Sample 126 (ID: 57_jpg.rf.46095db00eb3fcedceaec65446ed2891): Boxes shape=(1, 4)
# Sample 126 (ID: 57_jpg.rf.46095db00eb3fcedceaec65446ed2891): Labels shape=(1,)
# Sample 163 (ID: Y0030_test_jpg.rf.b9baeac4c6de87a64670cfdb227cdffd): Checking data...
# Sample 163 (ID: Y0030_test_jpg.rf.b9baeac4c6de87a64670cfdb227cdffd): Boxes shape=(1, 4)
# Sample 163 (ID: Y0030_test_jpg.rf.b9baeac4c6de87a64670cfdb227cdffd): Labels shape=(1,)
# Sample 164 (ID: 313_jpg.rf.af899899a669e0dfa8a801c3808ae447): Checking data...
# Sample 164 (ID: 313_jpg.rf.af899899a669e0dfa8a801c3808ae447): Boxes shape=(1, 4)
# Sample 164 (ID: 313_jpg.rf.af899899a669e0dfa8a801c3808ae447): Labels shape=(1,)
# Sample 165 (ID: hand2_x_bot_seg_1_cropped_jpeg.rf.ba622d4090d68347d3856bfff1abdb29): Checking data...
# Sample 165 (ID: hand2_x_bot_seg_1_cropped_jpeg.rf.ba622d4090d68347d3856bfff1abdb29): Boxes shape=(1, 4)
# Sample 165 (ID: hand2_x_bot_seg_1_cropped_jpeg.rf.ba622d4090d68347d3856bfff1abdb29): Labels shape=(1,)
# Sample 166 (ID: Q23_jpg.rf.8059db3fafff6ca09d66eee8d2a021dc): Checking data...
# Sample 166 (ID: Q23_jpg.rf.8059db3fafff6ca09d66eee8d2a021dc): Boxes shape=(1, 4)
# Sample 166 (ID: Q23_jpg.rf.8059db3fafff6ca09d66eee8d2a021dc): Labels shape=(1,)
# Sample 167 (ID: hand4_b_bot_seg_3_cropped_jpeg.rf.cdf9b0f6189c32c2498caad3441bfd14): Checking data...
# Sample 167 (ID: hand4_b_bot_seg_3_cropped_jpeg.rf.cdf9b0f6189c32c2498caad3441bfd14): Boxes shape=(1, 4)
# Sample 167 (ID: hand4_b_bot_seg_3_cropped_jpeg.rf.cdf9b0f6189c32c2498caad3441bfd14): Labels shape=(1,)
# Sample 168 (ID: U2899_jpg.rf.94bad34e3deea78d45c120d6c3a95cfb): Checking data...
# Sample 168 (ID: U2899_jpg.rf.94bad34e3deea78d45c120d6c3a95cfb): Boxes shape=(1, 4)
# Sample 168 (ID: U2899_jpg.rf.94bad34e3deea78d45c120d6c3a95cfb): Labels shape=(1,)
# Sample 169 (ID: A737_jpg.rf.d036eb1abed1b7471bae2602dfbb6192): Checking data...
# Sample 169 (ID: A737_jpg.rf.d036eb1abed1b7471bae2602dfbb6192): Boxes shape=(1, 4)
# Sample 169 (ID: A737_jpg.rf.d036eb1abed1b7471bae2602dfbb6192): Labels shape=(1,)
# Sample 170 (ID: U17_jpg.rf.817ad6f0a8731c1ee48c19a1ad558485): Checking data...
# Sample 170 (ID: U17_jpg.rf.817ad6f0a8731c1ee48c19a1ad558485): Boxes shape=(1, 4)
# Sample 170 (ID: U17_jpg.rf.817ad6f0a8731c1ee48c19a1ad558485): Labels shape=(1,)
# Sample 171 (ID: 41_jpg.rf.60dcd8f2edde3566d95e288efe550f26): Checking data...
# Sample 171 (ID: 41_jpg.rf.60dcd8f2edde3566d95e288efe550f26): Boxes shape=(1, 4)
# Sample 171 (ID: 41_jpg.rf.60dcd8f2edde3566d95e288efe550f26): Labels shape=(1,)
# Sample 9866 (ID: 143_jpg.rf.8dab1807563b1880e645d7e60998ff65): Labels shape=(1,)
# Sample 9867 (ID: 20_jpg.rf.2ea6b57ba282ae7d9b115293523950e3): Checking data...
# Sample 9867 (ID: 20_jpg.rf.2ea6b57ba282ae7d9b115293523950e3): Boxes shape=(1, 4)
# Sample 9867 (ID: 20_jpg.rf.2ea6b57ba282ae7d9b115293523950e3): Labels shape=(1,)
# Sample 9868 (ID: hand2_e_top_seg_5_cropped_jpeg.rf.021e2e17e02b2acc9156fab08b801db8): Checking data...
# Sample 9868 (ID: hand2_e_top_seg_5_cropped_jpeg.rf.021e2e17e02b2acc9156fab08b801db8): Boxes shape=(1, 4)
# Sample 9868 (ID: hand2_e_top_seg_5_cropped_jpeg.rf.021e2e17e02b2acc9156fab08b801db8): Labels shape=(1,)
# Sample 9869 (ID: V2715_jpg.rf.cd8b0f70fa16819f991dc73031f4b528): Checking data...
# Sample 9869 (ID: V2715_jpg.rf.cd8b0f70fa16819f991dc73031f4b528): Boxes shape=(1, 4)
# Sample 9869 (ID: V2715_jpg.rf.cd8b0f70fa16819f991dc73031f4b528): Labels shape=(1,)
# Sample 9870 (ID: E18_jpg.rf.35b6ee4d8f5a4f93b5aa8d5482417216): Checking data...
# Sample 9870 (ID: E18_jpg.rf.35b6ee4d8f5a4f93b5aa8d5482417216): Boxes shape=(1, 4)
# Sample 9870 (ID: E18_jpg.rf.35b6ee4d8f5a4f93b5aa8d5482417216): Labels shape=(1,)
# Sample 9871 (ID: N0_jpg.rf.77a9f6388be117d45e0a5999c021d2f5): Checking data...
# Sample 9871 (ID: N0_jpg.rf.77a9f6388be117d45e0a5999c021d2f5): Boxes shape=(1, 4)
# Sample 9871 (ID: N0_jpg.rf.77a9f6388be117d45e0a5999c021d2f5): Labels shape=(1,)
# Sample 9872 (ID: hand1_w_left_seg_4_cropped_jpeg.rf.1820aacf0d8ba52b3ff63dedcfe81705): Checking data...
# Sample 9872 (ID: hand1_w_left_seg_4_cropped_jpeg.rf.1820aacf0d8ba52b3ff63dedcfe81705): Boxes shape=(1, 4)
# Sample 9872 (ID: hand1_w_left_seg_4_cropped_jpeg.rf.1820aacf0d8ba52b3ff63dedcfe81705): Labels shape=(1,)
# Sample 9873 (ID: Q3_jpg.rf.9c19abc691f796348d6efc81c4cef592): Checking data...
# Sample 9873 (ID: Q3_jpg.rf.9c19abc691f796348d6efc81c4cef592): Boxes shape=(1, 4)
# Sample 9873 (ID: Q3_jpg.rf.9c19abc691f796348d6efc81c4cef592): Labels shape=(1,)
# Sample 9874 (ID: hand4_x_bot_seg_2_cropped_jpeg.rf.9ee30af88a9e8161d182cd94d0b07333): Checking data...
# Sample 9874 (ID: hand4_x_bot_seg_2_cropped_jpeg.rf.9ee30af88a9e8161d182cd94d0b07333): Boxes shape=(1, 4)
# Sample 9874 (ID: hand4_x_bot_seg_2_cropped_jpeg.rf.9ee30af88a9e8161d182cd94d0b07333): Labels shape=(1,)
# Sample 9875 (ID: A9_jpg.rf.35b6a0735e0ff6acc94df948b5314389): Checking data...
# Sample 9884 (ID: U16_jpg.rf.a45d33b7e7f6535a019d3b8da8a45616): Checking data...
# Sample 9884 (ID: U16_jpg.rf.a45d33b7e7f6535a019d3b8da8a45616): Boxes shape=(1, 4)
# Sample 9884 (ID: U16_jpg.rf.a45d33b7e7f6535a019d3b8da8a45616): Labels shape=(1,)
# Sample 9885 (ID: D2761_jpg.rf.314e5be8205647095002c966eaa6d15b): Checking data...
# Sample 9885 (ID: D2761_jpg.rf.314e5be8205647095002c966eaa6d15b): Boxes shape=(1, 4)
# Sample 9885 (ID: D2761_jpg.rf.314e5be8205647095002c966eaa6d15b): Labels shape=(1,)
# Sample 9886 (ID: M0026_test_jpg.rf.fe7271b589f9644bb69edcbca45d7db7): Checking data...
# Sample 9886 (ID: M0026_test_jpg.rf.fe7271b589f9644bb69edcbca45d7db7): Boxes shape=(1, 4)
# Sample 9886 (ID: M0026_test_jpg.rf.fe7271b589f9644bb69edcbca45d7db7): Labels shape=(1,)
# Sample 9887 (ID: 54_jpg.rf.46e90b36d40934e506685c2321e92ada): Checking data...
# Sample 9887 (ID: 54_jpg.rf.46e90b36d40934e506685c2321e92ada): Boxes shape=(1, 4)
# Sample 9887 (ID: 54_jpg.rf.46e90b36d40934e506685c2321e92ada): Labels shape=(1,)
# Sample 9888 (ID: hand2_n_top_seg_4_cropped_jpeg.rf.55974e60c6881d256f26bf5d5a3a1d2f): Checking data...
# Sample 9888 (ID: hand2_n_top_seg_4_cropped_jpeg.rf.55974e60c6881d256f26bf5d5a3a1d2f): Boxes shape=(1, 4)
# Sample 9888 (ID: hand2_n_top_seg_4_cropped_jpeg.rf.55974e60c6881d256f26bf5d5a3a1d2f): Labels shape=(1,)
# Sample 9889 (ID: 198_jpg.rf.698b67451f9634cb42c8d9444c407b45): Checking data...
# Sample 9889 (ID: 198_jpg.rf.698b67451f9634cb42c8d9444c407b45): Boxes shape=(1, 4)
# Sample 9889 (ID: 198_jpg.rf.698b67451f9634cb42c8d9444c407b45): Labels shape=(1,)
# Sample 9890 (ID: hand3_z_dif_seg_1_cropped_jpeg.rf.9d955fb13131563661720792a67402db): Checking data...
# Sample 9890 (ID: hand3_z_dif_seg_1_cropped_jpeg.rf.9d955fb13131563661720792a67402db): Boxes shape=(1, 4)
# Sample 9890 (ID: hand3_z_dif_seg_1_cropped_jpeg.rf.9d955fb13131563661720792a67402db): Labels shape=(1,)
# Sample 9891 (ID: hand3_q_dif_seg_2_cropped_jpeg.rf.f99581e7f13990cb074fcc10fe7fb17a): Checking data...
# Sample 9891 (ID: hand3_q_dif_seg_2_cropped_jpeg.rf.f99581e7f13990cb074fcc10fe7fb17a): Boxes shape=(1, 4)
# Sample 9891 (ID: hand3_q_dif_seg_2_cropped_jpeg.rf.f99581e7f13990cb074fcc10fe7fb17a): Labels shape=(1,)
# Sample 9892 (ID: hand5_u_bot_seg_1_cropped_jpeg.rf.75e4a18d0ec58be159090a9c2ec92fd0): Checking data...
# Sample 9892 (ID: hand5_u_bot_seg_1_cropped_jpeg.rf.75e4a18d0ec58be159090a9c2ec92fd0): Boxes shape=(1, 4)
# Sample 9892 (ID: hand5_u_bot_seg_1_cropped_jpeg.rf.75e4a18d0ec58be159090a9c2ec92fd0): Labels shape=(1,)
# Sample 9893 (ID: T0021_test_jpg.rf.ff41bda9b7686330deea270b98f4f606): Checking data...
# Sample 9893 (ID: T0021_test_jpg.rf.ff41bda9b7686330deea270b98f4f606): Boxes shape=(1, 4)
# Sample 9893 (ID: T0021_test_jpg.rf.ff41bda9b7686330deea270b98f4f606): Labels shape=(1,)
# Sample 9894 (ID: E10_jpg.rf.c73e3ba9aae6635fdad9617ba93f7b92): Checking data...
# Sample 9894 (ID: E10_jpg.rf.c73e3ba9aae6635fdad9617ba93f7b92): Boxes shape=(1, 4)
# Sample 9894 (ID: E10_jpg.rf.c73e3ba9aae6635fdad9617ba93f7b92): Labels shape=(1,)
# No problematic samples found in the dataset.

# %%
import argparse
import os
import logging
import sys
import itertools

import torch
from torch.utils.data import DataLoader, ConcatDataset
from torch.optim.lr_scheduler import CosineAnnealingLR, MultiStepLR

from vision.utils.misc import str2bool, Timer, freeze_net_layers, store_labels
from vision.ssd.ssd import MatchPrior
# from vision.ssd.vgg_ssd import create_vgg_ssd
# from vision.ssd.mobilenetv1_ssd import create_mobilenetv1_ssd
# from vision.ssd.mobilenetv1_ssd_lite import create_mobilenetv1_ssd_lite
from vision.ssd.mobilenet_v2_ssd_lite import create_mobilenetv2_ssd_lite
# from vision.ssd.squeezenet_ssd_lite import create_squeezenet_ssd_lite
from vision.datasets.slr_dataset import SLRDataset
from vision.datasets.open_images import OpenImagesDataset
from vision.nn.multibox_loss import MultiboxLoss
# from vision.ssd.config import vgg_ssd_config
from vision.ssd.config import mobilenetv1_ssd_config
# from vision.ssd.config import squeezenet_ssd_config
from vision.ssd.data_preprocessing import TrainAugmentation, TestTransform

from vision.ssd.mobilenet_v3_ssd_lite import create_mobilenetv3_ssd_lite
from config import default_config as cfg  # Import the default config instance



logging.basicConfig(stream=sys.stdout, level=logging.INFO,
                    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s')

DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

if torch.cuda.is_available():
    torch.backends.cudnn.benchmark = True
    logging.info("Use Cuda.")


def train(loader, net, criterion, optimizer, device, debug_steps=100, epoch=-1):
    net.train(True)
    running_loss = 0.0
    running_regression_loss = 0.0
    running_classification_loss = 0.0
    for i, data in enumerate(loader):
        images, boxes, labels = data
        images = images.to(device)
        boxes = boxes.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()
        confidence, locations = net(images)
        regression_loss, classification_loss = criterion(confidence, locations, labels, boxes)  # TODO CHANGE BOXES
        loss = regression_loss + classification_loss
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        running_regression_loss += regression_loss.item()
        running_classification_loss += classification_loss.item()
        if i and i % debug_steps == 0:
            avg_loss = running_loss / debug_steps
            avg_reg_loss = running_regression_loss / debug_steps
            avg_clf_loss = running_classification_loss / debug_steps
            logging.info(
                f"Epoch: {epoch}, Step: {i}, " +
                f"Average Loss: {avg_loss:.4f}, " +
                f"Average Regression Loss {avg_reg_loss:.4f}, " +
                f"Average Classification Loss: {avg_clf_loss:.4f}"
            )
            running_loss = 0.0
            running_regression_loss = 0.0
            running_classification_loss = 0.0


def test(loader, net, criterion, device):
    net.eval()
    running_loss = 0.0
    running_regression_loss = 0.0
    running_classification_loss = 0.0
    num = 0
    for _, data in enumerate(loader):
        images, boxes, labels = data
        images = images.to(device)
        boxes = boxes.to(device)
        labels = labels.to(device)
        num += 1

        with torch.no_grad():
            confidence, locations = net(images)
            regression_loss, classification_loss = criterion(confidence, locations, labels, boxes)
            loss = regression_loss + classification_loss

        running_loss += loss.item()
        running_regression_loss += regression_loss.item()
        running_classification_loss += classification_loss.item()
    return running_loss / num, running_regression_loss / num, running_classification_loss / num


if __name__ == '__main__':
    timer = Timer()

    logging.info(cfg)
    if cfg.net == 'mb2-ssd-lite':
        create_net = lambda num: create_mobilenetv2_ssd_lite(num, width_mult=cfg.mb2_width_mult)
        config = mobilenetv1_ssd_config
    elif cfg.net == 'mb3-ssd-lite':
        create_net = lambda num: create_mobilenetv3_ssd_lite(num)
        config = mobilenetv1_ssd_config
    else:
        logging.fatal("The net type is wrong.")
        parser.print_help(sys.stderr)
        sys.exit(1)
    train_transform = TrainAugmentation(config.image_size, config.image_mean, config.image_std)
    target_transform = MatchPrior(config.priors, config.center_variance,
                                  config.size_variance, 0.5)

    test_transform = TestTransform(config.image_size, config.image_mean, config.image_std)

    logging.info("Prepare training datasets.")
    datasets = []
    
    # Add this before trying to store labels
    os.makedirs(cfg.checkpoint_folder, exist_ok=True)
    
    for dataset_path in cfg.datasets:
        if cfg.dataset_type == 'slr':
            dataset = SLRDataset(dataset_path, transform=train_transform,
                                 target_transform=target_transform)
            label_file = os.path.join(cfg.checkpoint_folder, "slr-model-labels.txt")
            store_labels(label_file, dataset.class_names)
            num_classes = len(dataset.class_names)
        elif cfg.dataset_type == 'open_images':
            dataset = OpenImagesDataset(dataset_path,
                 transform=train_transform, target_transform=target_transform,
                 dataset_type="train", balance_data=cfg.balance_data)
            label_file = os.path.join(cfg.checkpoint_folder, "open-images-model-labels.txt")
            store_labels(label_file, dataset.class_names)
            logging.info(dataset)
            num_classes = len(dataset.class_names)

        else:
            raise ValueError(f"Dataset tpye {cfg.dataset_type} is not supported.")
        datasets.append(dataset)
    logging.info(f"Stored labels into file {label_file}.")
    train_dataset = ConcatDataset(datasets)
    logging.info("Train dataset size: {}".format(len(train_dataset)))
    train_loader = DataLoader(train_dataset, cfg.batch_size,
                              num_workers=cfg.num_workers,
                              shuffle=True,
                              drop_last=True)
    logging.info("Prepare Validation datasets.")
    if cfg.dataset_type == "slr":
        val_dataset = SLRDataset(cfg.validation_dataset, transform=test_transform,
                                 target_transform=target_transform, is_test=True)
    elif cfg.dataset_type == 'open_images':
        val_dataset = OpenImagesDataset(dataset_path,
                                        transform=test_transform, target_transform=target_transform,
                                        dataset_type="test")
        logging.info(val_dataset)
    logging.info("validation dataset size: {}".format(len(val_dataset)))

    val_loader = DataLoader(val_dataset, cfg.batch_size,
                            num_workers=cfg.num_workers,
                            shuffle=False,
                            drop_last=True)
    logging.info("Build network.")
    net = create_net(num_classes)
    #print(net)

  


    min_loss = -10000.0
    last_epoch = -1

    base_net_lr = cfg.base_net_lr if cfg.base_net_lr is not None else cfg.lr
    extra_layers_lr = cfg.extra_layers_lr if cfg.extra_layers_lr is not None else cfg.lr
    if cfg.freeze_base_net:
        logging.info("Freeze base net.")
        freeze_net_layers(net.base_net)
        params = itertools.chain(net.source_layer_add_ons.parameters(), net.extras.parameters(),
                                 net.regression_headers.parameters(), net.classification_headers.parameters())
        params = [
            {'params': itertools.chain(
                net.source_layer_add_ons.parameters(),
                net.extras.parameters()
            ), 'lr': extra_layers_lr},
            {'params': itertools.chain(
                net.regression_headers.parameters(),
                net.classification_headers.parameters()
            )}
        ]
    elif cfg.freeze_net:
        freeze_net_layers(net.base_net)
        freeze_net_layers(net.source_layer_add_ons)
        freeze_net_layers(net.extras)
        params = itertools.chain(net.regression_headers.parameters(), net.classification_headers.parameters())
        logging.info("Freeze all the layers except prediction heads.")
    else:
        params = [
            {'params': net.base_net.parameters(), 'lr': base_net_lr},
            {'params': itertools.chain(
                net.source_layer_add_ons.parameters(),
                net.extras.parameters()
            ), 'lr': extra_layers_lr},
            {'params': itertools.chain(
                net.regression_headers.parameters(),
                net.classification_headers.parameters()
            )}
        ]

    timer.start("Load Model")
    if cfg.resume:
        logging.info(f"Resume from the model {cfg.resume}")
        net.load(cfg.resume)
    elif cfg.base_net:
        logging.info(f"Init from base net {cfg.base_net}")
        net.init_from_base_net(cfg.base_net)
    elif cfg.pretrained_ssd:
        logging.info(f"Init from pretrained ssd {cfg.pretrained_ssd}")
        net.init_from_pretrained_ssd(cfg.pretrained_ssd)
    logging.info(f'Took {timer.end("Load Model"):.2f} seconds to load the model.')

    net.to(DEVICE)

    criterion = MultiboxLoss(config.priors, iou_threshold=0.5, neg_pos_ratio=3,
                             center_variance=0.1, size_variance=0.2, device=DEVICE)
    optimizer = torch.optim.SGD(params, lr=cfg.lr, momentum=cfg.momentum,
                                weight_decay=cfg.weight_decay)
    logging.info(f"Learning rate: {cfg.lr}, Base net learning rate: {base_net_lr}, "
                 + f"Extra Layers learning rate: {extra_layers_lr}.")

    if cfg.scheduler == 'multi-step':
        logging.info("Uses MultiStepLR scheduler.")
        milestones = [int(v.strip()) for v in cfg.milestones.split(",")]
        scheduler = MultiStepLR(optimizer, milestones=milestones,
                                                     gamma=0.1, last_epoch=last_epoch)
    elif cfg.scheduler == 'cosine':
        logging.info("Uses CosineAnnealingLR scheduler.")
        scheduler = CosineAnnealingLR(optimizer, cfg.t_max, last_epoch=last_epoch)
    else:
        logging.fatal(f"Unsupported Scheduler: {cfg.scheduler}.")
        parser.print_help(sys.stderr)
        sys.exit(1)

    logging.info(f"Start training from epoch {last_epoch + 1}.")

    #sys.exit(0)#test


    for epoch in range(last_epoch + 1, cfg.num_epochs):
        scheduler.step()
        train(train_loader, net, criterion, optimizer,
              device=DEVICE, debug_steps=cfg.debug_steps, epoch=epoch)
        
        if epoch % cfg.validation_epochs == 0 or epoch == cfg.num_epochs - 1:
            val_loss, val_regression_loss, val_classification_loss = test(val_loader, net, criterion, DEVICE)
            logging.info(
                f"Epoch: {epoch}, " +
                f"Validation Loss: {val_loss:.4f}, " +
                f"Validation Regression Loss {val_regression_loss:.4f}, " +
                f"Validation Classification Loss: {val_classification_loss:.4f}"
            )
            model_path = os.path.join(cfg.checkpoint_folder, f"{cfg.net}-Epoch-{epoch}-Loss-{val_loss}.pth")
            net.save(model_path)
            logging.info(f"Saved model {model_path}")
# Out:
# RandomSampleCrop initialized with: [None, (0.1, None), (0.3, None), (0.7, None), (0.9, None), (None, None)]
# Before random.choice, sample_options: [None, (0.1, None), (0.3, None), (0.7, None), (0.9, None), (None, None)]
# Error in random.choice with sample_options: [None, (0.1, None), (0.3, None), (0.7, None), (0.9, None), (None, None)]
# Before random.choice, sample_options: [None, (0.1, None), (0.3, None), (0.7, None), (0.9, None), (None, None)]
# Error in random.choice with sample_options: [None, (0.1, None), (0.3, None), (0.7, None), (0.9, None), (None, None)]
# Before random.choice, sample_options: [None, (0.1, None), (0.3, None), (0.7, None), (0.9, None), (None, None)]
# Error in random.choice with sample_options: [None, (0.1, None), (0.3, None), (0.7, None), (0.9, None), (None, None)]
# Before random.choice, sample_options:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 255
#     253 for epoch in range(last_epoch + 1, cfg.num_epochs):
#     254     scheduler.step()
# --> 255     train(train_loader, net, criterion, optimizer,
#     256           device=DEVICE, debug_steps=cfg.debug_steps, epoch=epoch)
#     258     if epoch % cfg.validation_epochs == 0 or epoch == cfg.num_epochs - 1:
#     259         val_loss, val_regression_loss, val_classification_loss = test(val_loader, net, criterion, DEVICE)
#
# Cell In[11], line 46, in train(loader, net, criterion, optimizer, device, debug_steps, epoch)
#      44 running_regression_loss = 0.0
#      45 running_classification_loss = 0.0
# ---> 46 for i, data in enumerate(loader):
#      47     images, boxes, labels = data
#      48     images = images.to(device)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/torch/utils/data/dataloader.py:708, in _BaseDataLoaderIter.__next__(self)
#     705 if self._sampler_iter is None:
#     706     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     707     self._reset()  # type: ignore[call-arg]
# --> 708 data = self._next_data()
#     709 self._num_yielded += 1
#     710 if (
#     711     self._dataset_kind == _DatasetKind.Iterable
#     712     and self._IterableDataset_len_called is not None
#     713     and self._num_yielded > self._IterableDataset_len_called
#     714 ):
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/torch/utils/data/dataloader.py:1480, in _MultiProcessingDataLoaderIter._next_data(self)
#    1478 del self._task_info[idx]
#    1479 self._rcvd_idx += 1
# -> 1480 return self._process_data(data)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/torch/utils/data/dataloader.py:1505, in _MultiProcessingDataLoaderIter._process_data(self, data)
#    1503 self._try_put_index()
#    1504 if isinstance(data, ExceptionWrapper):
# -> 1505     data.reraise()
#    1506 return data
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/torch/_utils.py:733, in ExceptionWrapper.reraise(self)
#     729 except TypeError:
#     730     # If the exception takes multiple arguments, don't try to
#     731     # instantiate since we don't know how to
#     732     raise RuntimeError(msg) from None
# --> 733 raise exception
#
# ValueError: Caught ValueError in DataLoader worker process 0.
# Original Traceback (most recent call last):
#   File "/home/dat/.pyenv/versions/3.11.7/lib/python3.11/site-packages/torch/utils/data/_utils/worker.py", line 349, in _worker_loop
#     data = fetcher.fetch(index)  # type: ignore[possibly-undefined]
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/dat/.pyenv/versions/3.11.7/lib/python3.11/site-packages/torch/utils/data/_utils/fetch.py", line 52, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dat/.pyenv/versions/3.11.7/lib/python3.11/site-packages/torch/utils/data/_utils/fetch.py", line 52, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#             ~~~~~~~~~~~~^^^^^
#   File "/home/dat/.pyenv/versions/3.11.7/lib/python3.11/site-packages/torch/utils/data/dataset.py", line 350, in __getitem__
#     return self.datasets[dataset_idx][sample_idx]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
#   File "/home/dat/2025/thesis/edgetpu_tflite_inference/train/vision/datasets/slr_dataset.py", line 64, in __getitem__
#   File "/home/dat/2025/thesis/edgetpu_tflite_inference/train/vision/ssd/data_preprocessing.py", line 34, in __call__
#     return self.augment(img, boxes, labels)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dat/2025/thesis/edgetpu_tflite_inference/train/vision/transforms/transforms.py", line 55, in __call__
#     for t in self.transforms:
#                              ^
#   File "/home/dat/2025/thesis/edgetpu_tflite_inference/train/vision/transforms/transforms.py", line 251, in __call__
#     print(f"Error in random.choice with sample_options: {self.sample_options}")
#     ^^^^^^^
#   File "/home/dat/2025/thesis/edgetpu_tflite_inference/train/vision/transforms/transforms.py", line 248, in __call__
#     try:
#
#   File "numpy/random/mtrand.pyx", line 956, in numpy.random.mtrand.RandomState.choice
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (6,) + inhomogeneous part.
#  [None, (0.1, None), (0.3, None), (0.7, None), (0.9, None), (None, None)]
# Error in random.choice with sample_options: [None, (0.1, None), (0.3, None), (0.7, None), (0.9, None), (None, None)]
# Before random.choice, sample_options: [None, (0.1, None), (0.3, None), (0.7, None), (0.9, None), (None, None)]
# Error in random.choice with sample_options: [None, (0.1, None), (0.3, None), (0.7, None), (0.9, None), (None, None)]
# Before random.choice, sample_options: [None, (0.1, None), (0.3, None), (0.7, None), (0.9, None), (None, None)]
# Error in random.choice with sample_options: [None, (0.1, None), (0.3, None), (0.7, None), (0.9, None), (None, None)]
# Before random.choice, sample_options:
#  [None, (0.1, None), (0.3, None), (0.7, None), (0.9, None), (None, None)]
# Error in random.choice with sample_options: [None, (0.1, None), (0.3, None), (0.7, None), (0.9, None), (None, None)]
# Before random.choice, sample_options: [None, (0.1, None), (0.3, None), (0.7, None), (0.9, None), (None, None)]
# Error in random.choice with sample_options: [None, (0.1, None), (0.3, None), (0.7, None), (0.9, None), (None, None)]
# Before random.choice, sample_options: [None, (0.1, None), (0.3, None), (0.7, None), (0.9, None), (None, None)]
# Error in random.choice with sample_options: [None, (0.1, None), (0.3, None), (0.7, None), (0.9, None), (None, None)]
